# %%
import pandas as pd
import numpy as np
import pixiedust
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import word_tokenize

# %%
data = 'data/cc_chunks.json'
df = pd.read_json(data)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-0a55bd747383> in <module>()
#       1 data = 'data/cc_chunks.json'
# ----> 2 df = pd.read_json(data)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     358         keep_default_dates=keep_default_dates, numpy=numpy,
#     359         precise_float=precise_float, date_unit=date_unit, encoding=encoding,
# --> 360         lines=lines, chunksize=chunksize, compression=compression,
#     361     )
#     362
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/json/json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     402
#     403         data = self._get_data_from_filepath(filepath_or_buffer)
# --> 404         self.data = self._preprocess_data(data)
#     405
#     406     def _preprocess_data(self, data):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/json/json.py in _preprocess_data(self, data)
#     413         """
#     414         if hasattr(data, 'read') and not self.chunksize:
# --> 415             data = data.read()
#     416         if not hasattr(data, 'read') and self.chunksize:
#     417             data = StringIO(data)
#
# OSError: [Errno 22] Invalid argument

# %%
max_records = 1
data = 'data/cc_chunks.json'
df = pd.read_json(data, lines=True, chunksize=max_records)
filtered_data = pd.DataFrame() # Initialize the dataframe
try:
    for df_chunk in df:
        filtered_data = pd.concat([filtered_data, df_chunk])
        
        break
except ValueError:
       print ('\nSome messages in the file cannot be parsed')
        
filtered_data.head()
# Out:
#                                     _id      channel  \
# 0  {'$oid': '5b4d62c727eca30007beed65'}  UNIMAS_KFTR
#
#                               created_at  duration  lang      machine_id  \
# 0  {'$date': '2018-07-17T03:30:15.231Z'}    900000  dflt  ENSWERCCR7_247
#
#                                  ts        tui  \
# 0  {'$numberLong': '1531797300000'}  251537479
#
#                                       tv  \
# 0  {'$date': '2018-07-17T03:15:00.000Z'}
#
#                                                  url  \
# 0  https://s3.amazonaws.com/adm-mpeg-dash/gnvideo...
#
#                                              zip_url
# 0  https://s3.amazonaws.com/adm-mpeg-dash/gnvideo...

# %%
filtered_data['url']
# Out:
# 0    https://s3.amazonaws.com/adm-mpeg-dash/gnvideo...
# Name: url, dtype: object

# %%
with open('data/example.txt') as f: 
    data = f.readlines() 

data
# Out:
# ['1533919500396\n',
#  '1068\n',
#  'YEAR SEAHAWKS TEAM INCLUDING\n',
#  'SOMEONE WHO IMPRESS A WHOLE LOT\n',
#  '\n',
#  '1533919501464\n',
#  '1134\n',
#  'SOMEONE WHO IMPRESS A WHOLE LOT\n',
#  'OF PEOPLE.\n',
#  '\n',
#  '1533919502599\n',
#  '834\n',
#  'OF PEOPLE.\n',
#  'ALL ACROSS THE COUNTRY WITH HIS\n',
#  '\n',
#  '1533919503433\n',
#  '2402\n',
#  'ALL ACROSS THE COUNTRY WITH HIS\n',
#  'DEBUT LAST NIGHT.\n',
#  '\n',
#  '1533919505835\n',
#  '2169\n',
#  'DEBUT LAST NIGHT.\n',
#  '>> EVERY FAN IN THE COUNTRY IS A\n',
#  '\n',
#  '1533919508004\n',
#  '2169\n',
#  '>> EVERY FAN IN THE COUNTRY IS A\n',
#  'FAN OF THIS GENTLEMAN.\n',
#  '\n',
#  '1533919510173\n',
#  '767\n',
#  'FAN OF THIS GENTLEMAN.\n',
#  'RECORDING 4 TACKLES IN HIS FIRST\n',
#  '\n',
#  '1533919510940\n',
#  '3670\n',
#  'RECORDING 4 TACKLES IN HIS FIRST\n',
#  '4 SNAPS.\n',
#  '\n',
#  '1533919514611\n',
#  '2202\n',
#  '4 SNAPS.\n',
#  'THE LEADING TACKLER IN THE GAME.\n',
#  '\n',
#  '1533919516813\n',
#  '1401\n',
#  'THE LEADING TACKLER IN THE GAME.\n',
#  'CLOSER LOOK AT THAT ROOKIE\n',
#  '\n',
#  '1533919518214\n',
#  '400\n',
#  'CLOSER LOOK AT THAT ROOKIE\n',
#  'LINEBACKER.\n',
#  '\n',
#  '1533919518615\n',
#  '3804\n',
#  'LINEBACKER.\n',
#  '>> MEET NUMBER 49.\n',
#  '\n',
#  '1533919522418\n',
#  '667\n',
#  '>> MEET NUMBER 49.\n',
#  'THE ATHLETIC LINEBACKER WAS\n',
#  '\n',
#  '1533919523086\n',
#  '1969\n',
#  'THE ATHLETIC LINEBACKER WAS\n',
#  'SELECTED BY THE SEAHAWKS IN THE\n',
#  '\n',
#  '1533919525054\n',
#  '701\n',
#  'SELECTED BY THE SEAHAWKS IN THE\n',
#  'FIFTH ROUND REUNITING HIM WITH\n',
#  '\n',
#  '1533919525755\n',
#  '1935\n',
#  'FIFTH ROUND REUNITING HIM WITH\n',
#  'HIS TWIN BROTHER.\n',
#  '\n',
#  '1533919527690\n',
#  '3003\n',
#  'HIS TWIN BROTHER.\n',
#  '>> HELLO.\n',
#  '\n',
#  '1533919530693\n',
#  '467\n',
#  '>> HELLO.\n',
#  '>> YES SIR.\n',
#  '\n',
#  '1533919531160\n',
#  '2769\n',
#  '>> YES SIR.\n',
#  'IT’S JOHN SCHNEIDER CALLING HOW\n',
#  '\n',
#  '1533919533929\n',
#  '3871\n',
#  'IT’S JOHN SCHNEIDER CALLING HOW\n',
#  'ARE YOU DOING?\n',
#  '\n',
#  '1533919537800\n',
#  '767\n',
#  'ARE YOU DOING?\n',
#  '>> I CAN’T EVEN BREATHE RIGHT\n',
#  '\n',
#  '1533919538567\n',
#  '267\n',
#  '>> I CAN’T EVEN BREATHE RIGHT\n',
#  'NOW.\n',
#  '\n',
#  '1533919538834\n',
#  '3003\n',
#  'NOW.\n',
#  '>> BOTH BROTHERS OFFERED\n',
#  '\n',
#  '1533919541837\n',
#  '968\n',
#  '>> BOTH BROTHERS OFFERED\n',
#  'SCHOLARSHIPS TO THE UNIVERSITY\n',
#  '\n',
#  '1533919542805\n',
#  '734\n',
#  'SCHOLARSHIPS TO THE UNIVERSITY\n',
#  'OF CENTRAL FLORIDA WHERE THEY\n',
#  '\n',
#  '1533919543539\n',
#  '4037\n',
#  'OF CENTRAL FLORIDA WHERE THEY\n',
#  'PLAYED TOGETHER.\n',
#  '\n',
#  '1533919547576\n',
#  '2836\n',
#  'PLAYED TOGETHER.\n',
#  'THE SENIOR YEAR SHE LEAD THE\n',
#  '\n',
#  '1533919550413\n',
#  '1535\n',
#  'THE SENIOR YEAR SHE LEAD THE\n',
#  'NINTH 21st EVER UNDEFEATED\n',
#  '\n',
#  '1533919551947\n',
#  '334\n',
#  'NINTH 21st EVER UNDEFEATED\n',
#  'RECORD.\n',
#  '\n',
#  '1533919552281\n',
#  '2035\n',
#  'RECORD.\n',
#  'FINISHING 13 AND 0 AND NAMED A\n',
#  '\n',
#  '1533919554316\n',
#  '1902\n',
#  'FINISHING 13 AND 0 AND NAMED A\n',
#  'SECOND-TEAM ALL-AMERICAN.\n',
#  '\n',
#  '1533919556218\n',
#  '1034\n',
#  'SECOND-TEAM ALL-AMERICAN.\n',
#  'GRIFFIN UNDER THE NFL DRAFT AND\n',
#  '\n',
#  '1533919557253\n',
#  '2769\n',
#  'GRIFFIN UNDER THE NFL DRAFT AND\n',
#  '1 OF THE LAST TO BE INVITED TO\n',
#  '\n',
#  '1533919560022\n',
#  '1168\n',
#  '1 OF THE LAST TO BE INVITED TO\n',
#  'THE NFL COMBINE WHERE HE WOWED\n',
#  '\n',
#  '1533919561190\n',
#  '1235\n',
#  'THE NFL COMBINE WHERE HE WOWED\n',
#  'THE SCOUTS.\n',
#  '\n',
#  '1533919562425\n',
#  '3103\n',
#  'THE SCOUTS.\n',
#  'RAN A 4.3840-YARD-AND PUT UP 20\n',
#  '\n',
#  '1533919565528\n',
#  '1702\n',
#  'RAN A 4.3840-YARD-AND PUT UP 20\n',
#  'REPS ON THE BENCH PRESS USING A\n',
#  '\n',
#  '1533919567229\n',
#  '868\n',
#  'REPS ON THE BENCH PRESS USING A\n',
#  'SPECIAL PROSTHETIC STRAPPED TO\n',
#  '\n',
#  '1533919568097\n',
#  '2503\n',
#  'SPECIAL PROSTHETIC STRAPPED TO\n',
#  'HIS LEFT ARM.\n',
#  '\n',
#  '1533919570599\n',
#  '1401\n',
#  'HIS LEFT ARM.\n',
#  'HE LOST HIS LEFT HAND DUE TO A\n',
#  '\n',
#  '1533919572001\n',
#  '2236\n',
#  'HE LOST HIS LEFT HAND DUE TO A\n',
#  'RARE CONDITION AT THE AGE OF 4.\n',
#  '\n',
#  '1533919574236\n',
#  '1969\n',
#  'RARE CONDITION AT THE AGE OF 4.\n',
#  'AND YOU CAN TELL THAT HASN’T\n',
#  '\n',
#  '1533919576205\n',
#  '467\n',
#  'AND YOU CAN TELL THAT HASN’T\n',
#  'STOPPED HIM.\n',
#  '\n',
#  '1533919576672\n',
#  '1235\n',
#  'STOPPED HIM.\n',
#  'HIS BROTHER SAYS HE AND THE TEAM\n',
#  '\n',
#  '1533919577907\n',
#  '1702\n',
#  'HIS BROTHER SAYS HE AND THE TEAM\n',
#  'ARE GLAD TO HAVE HIM.\n',
#  '\n',
#  '1533919579608\n',
#  '1468\n',
#  'ARE GLAD TO HAVE HIM.\n',
#  '>> I KNOW HE’S GOING TO WORK\n',
#  '\n',
#  '1533919581077\n',
#  '701\n',
#  '>> I KNOW HE’S GOING TO WORK\n',
#  'HARD AND PUSH EVERYBODY AROUND\n',
#  '\n',
#  '1533919581777\n',
#  '1401\n',
#  'HARD AND PUSH EVERYBODY AROUND\n',
#  'HIM.\n',
#  '\n',
#  '1533919583179\n',
#  '2936\n',
#  'HIM.\n',
#  'THAT’S HOW I MAKE PLAYS.\n',
#  '\n',
#  '1533919586115\n',
#  '1468\n',
#  'THAT’S HOW I MAKE PLAYS.\n',
#  'WE BRING THE ATMOSPHERE BACK\n',
#  '\n',
#  '1533919587583\n',
#  '1802\n',
#  'WE BRING THE ATMOSPHERE BACK\n',
#  'TRYING TO BEAT EACH OTHER OUT\n',
#  '\n',
#  '1533919589385\n',
#  '1235\n',
#  'TRYING TO BEAT EACH OTHER OUT\n',
#  'EVERYTHING AS A COMPETITION.\n',
#  '\n',
#  '1533919590619\n',
#  '1802\n',
#  'EVERYTHING AS A COMPETITION.\n',
#  'WHAT HE BRINGS TO THE TABLE HIGH\n',
#  '\n',
#  '1533919592421\n',
#  '767\n',
#  'WHAT HE BRINGS TO THE TABLE HIGH\n',
#  'ENERGY AND YOU CAN TELL HE LOVES\n',
#  '\n',
#  '1533919593189\n',
#  '1401\n',
#  'ENERGY AND YOU CAN TELL HE LOVES\n',
#  'THE GAME AND BOTH PASSIONATE\n',
#  '\n',
#  '1533919594590\n',
#  '1869\n',
#  'THE GAME AND BOTH PASSIONATE\n',
#  'ABOUT IT.\n',
#  '\n',
#  '1533919596459\n',
#  '2936\n',
#  'ABOUT IT.\n',
#  'HIS PRESENCE ALONE IS A GREAT\n',
#  '\n',
#  '1533919599395\n',
#  '2169\n',
#  'HIS PRESENCE ALONE IS A GREAT\n',
#  'FOR EVERYBODY.\n',
#  '\n',
#  '1533919601564\n',
#  '834\n',
#  'FOR EVERYBODY.\n',
#  '>> LIKELY PLAY WEAK SIDE\n',
#  '\n',
#  '1533919602398\n',
#  '801\n',
#  '>> LIKELY PLAY WEAK SIDE\n',
#  'LINEBACKER ON DEFENSE AND\n',
#  '\n',
#  '1533919603199\n',
#  '734\n',
#  'LINEBACKER ON DEFENSE AND\n',
#  'CONTRIBUTE ON SPECIAL TEAMS IN\n',
#  '\n',
#  '1533919603933\n',
#  '3270\n',
#  'CONTRIBUTE ON SPECIAL TEAMS IN\n',
#  'THE ROOKIE YEAR.\n',
#  '\n',
#  '1533919607203\n',
#  '2402\n',
#  'THE ROOKIE YEAR.\n',
#  '>> WE HAVE MORE OF THESE STORIES\n',
#  '\n',
#  '1533919609605\n',
#  '667\n',
#  '>> WE HAVE MORE OF THESE STORIES\n',
#  'COMING YOUR WAY.\n',
#  '\n',
#  '1533919610272\n',
#  '1201\n',
#  'COMING YOUR WAY.\n',
#  'NEXT WEEK WILL LEARN ALL ABOUT\n',
#  '\n',
#  '1533919611474\n',
#  '734\n',
#  'NEXT WEEK WILL LEARN ALL ABOUT\n',
#  'EVERYBODY ELSE FROM NEW OFFENSE\n',
#  '\n',
#  '1533919612208\n',
#  '7941\n',
#  'EVERYBODY ELSE FROM NEW OFFENSE\n',
#  'OF COORDINATOR TO NEW\n',
#  '\n',
#  '1533919620149\n',
#  '6440\n',
#  'OF COORDINATOR TO NEW\n',
#  'CORNERBACK TRE FLOWERS.\n',
#  '\n',
#  '1533919626589\n',
#  '801\n',
#  'CORNERBACK TRE FLOWERS.\n',
#  '>> I AM CAUTIOUSLY OPTIMISTIC\n',
#  '\n',
#  '1533919627389\n',
#  '601\n',
#  '>> I AM CAUTIOUSLY OPTIMISTIC\n',
#  'ABOUT THE OFFENSE.\n',
#  '\n',
#  '1533919627990\n',
#  '1001\n',
#  'ABOUT THE OFFENSE.\n',
#  'I LIKE WHAT THEY’VE DONE WITH\n',
#  '\n',
#  '1533919628991\n',
#  '1735\n',
#  'I LIKE WHAT THEY’VE DONE WITH\n',
#  'THE OFFENSE OF LINE AND\n',
#  '\n',
#  '1533919630726\n',
#  '701\n',
#  'THE OFFENSE OF LINE AND\n',
#  'BACKFIELD AND WE HAVE THAT GUY\n',
#  '\n',
#  '1533919631427\n',
#  '3737\n',
#  'BACKFIELD AND WE HAVE THAT GUY\n',
#  'NUMBER 3 WHO CAN DO SOME THINGS.\n',
#  '\n',
#  '1533919635164\n',
#  '501\n',
#  'NUMBER 3 WHO CAN DO SOME THINGS.\n',
#  '>> ALL RIGHT.\n',
#  '\n',
#  '1533919635664\n',
#  '2903\n',
#  '>> ALL RIGHT.\n',
#  'SOUNDS GOOD.\n',
#  '\n',
#  '1533919638567\n',
#  '501\n',
#  'SOUNDS GOOD.\n',
#  'LET’S GO TO MJ.\n',
#  '\n',
#  '1533919639068\n',
#  '2936\n',
#  'LET’S GO TO MJ.\n',
#  '>> WATCHING THE GAME LAST NIGHT\n',
#  '\n',
#  '1533919642004\n',
#  '1602\n',
#  '>> WATCHING THE GAME LAST NIGHT\n',
#  'FLOWERS AT THAT COACH COULD GO\n',
#  '\n',
#  '1533919643606\n',
#  '1068\n',
#  'FLOWERS AT THAT COACH COULD GO\n',
#  'LIKE BRING ME FLOWERS AND THEY\n',
#  '\n',
#  '1533919644673\n',
#  '634\n',
#  'LIKE BRING ME FLOWERS AND THEY\n',
#  'WOULD BRING HIM A BUNCH OF\n',
#  '\n',
#  '1533919645307\n',
#  '3704\n',
#  'WOULD BRING HIM A BUNCH OF\n',
#  'FLOWERS.\n',
#  '\n',
#  '1533919649011\n',
#  '334\n',
#  'FLOWERS.\n',
#  'ANYWAY.\n',
#  '\n',
#  '1533919649345\n',
#  '1034\n',
#  'ANYWAY.\n',
#  'GRAYSCALE DIRECTOR, AND OLYMPIA\n',
#  '\n',
#  '1533919650379\n',
#  '1468\n',
#  'GRAYSCALE DIRECTOR, AND OLYMPIA\n',
#  'THE U-DISTRICT KIND OF HAZY WITH\n',
#  '\n',
#  '1533919651847\n',
#  '1068\n',
#  'THE U-DISTRICT KIND OF HAZY WITH\n',
#  'THE SMOKE OUT THERE.\n',
#  '\n',
#  '1533919652915\n',
#  '2269\n',
#  'THE SMOKE OUT THERE.\n',
#  'CLOUDY ON THE COAST IN LOOKING\n',
#  '\n',
#  '1533919655184\n',
#  '534\n',
#  'CLOUDY ON THE COAST IN LOOKING\n',
#  'HAZY AND BELLINGHAM.\n',
#  '\n',
#  '1533919655718\n',
#  '1835\n',
#  'HAZY AND BELLINGHAM.\n',
#  'THAT WILL BE THE THEME TODAY THE\n',
#  '\n',
#  '1533919657553\n',
#  '1368\n',
#  'THAT WILL BE THE THEME TODAY THE\n',
#  'HAZY SUNSHINE BUT ALSO GOING TO\n',
#  '\n',
#  '1533919658921\n',
#  '1134\n',
#  'HAZY SUNSHINE BUT ALSO GOING TO\n',
#  'COOL DOWN.\n',
#  '\n',
#  '1533919660055\n',
#  '3270\n',
#  'COOL DOWN.\n',
#  '71 IN SEATTLE RAIN L73 OR 74 BY\n',
#  '\n',
#  '1533919663325\n',
#  '1668\n',
#  '71 IN SEATTLE RAIN L73 OR 74 BY\n',
#  'LUNCHTIME AND 83 FOR THE HIGH.\n',
#  '\n',
#  '1533919664994\n',
#  '3036\n',
#  'LUNCHTIME AND 83 FOR THE HIGH.\n',
#  'WHICH IS WARM BUT YESTERDAY WE\n',
#  '\n',
#  '1533919668030\n',
#  '868\n',
#  'WHICH IS WARM BUT YESTERDAY WE\n',
#  'HIT 93 AND OVERNIGHT TONIGHT\n',
#  '\n',
#  '1533919668898\n',
#  '2536\n',
#  'HIT 93 AND OVERNIGHT TONIGHT\n',
#  'THAT WAS A RAIN ICON A CHANCE OF\n',
#  '\n',
#  '1533919671433\n',
#  '1001\n',
#  'THAT WAS A RAIN ICON A CHANCE OF\n',
#  'SHOWERS OVERNIGHT INTO TOMORROW\n',
#  '\n',
#  '1533919672434\n',
#  '2002\n',
#  'SHOWERS OVERNIGHT INTO TOMORROW\n',
#  'WITH HIGH OF ONLY 71 TOMORROW.\n',
#  '\n',
#  '1533919674436\n',
#  '2769\n',
#  'WITH HIGH OF ONLY 71 TOMORROW.\n',
#  'A CHANCE OF A THUNDERSTORM AND\n',
#  '\n',
#  '1533919677206\n',
#  '1668\n',
#  'A CHANCE OF A THUNDERSTORM AND\n',
#  'SUNDAY MORNING CLOUDS AFTERNOON\n',
#  '\n',
#  '1533919678874\n',
#  '1768\n',
#  'SUNDAY MORNING CLOUDS AFTERNOON\n',
#  'CLEARING 78 FOR THE HIGH.\n',
#  '\n',
#  '1533919680643\n',
#  '734\n',
#  'CLEARING 78 FOR THE HIGH.\n',
#  'COMFORTABLE.\n',
#  '\n',
#  '1533919681377\n',
#  '2803\n',
#  'COMFORTABLE.\n',
#  'THAT METEOR SHOWER SUNDAY NIGHT\n',
#  '\n',
#  '1533919684179\n',
#  '734\n',
#  'THAT METEOR SHOWER SUNDAY NIGHT\n',
#  'INTO MONDAY PEAKS AND WE SHOULD\n',
#  '\n',
#  '1533919684914\n',
#  '767\n',
#  'INTO MONDAY PEAKS AND WE SHOULD\n',
#  'HAVE CLEAR SKIES SUNDAY NIGHT TO\n',
#  '\n',
#  '1533919685681\n',
#  '1401\n',
#  'HAVE CLEAR SKIES SUNDAY NIGHT TO\n',
#  'GET AWAY FROM CITY LIGHTS AND\n',
#  '\n',
#  '1533919687082\n',
#  '767\n',
#  'GET AWAY FROM CITY LIGHTS AND\n',
#  'HOPEFULLY THE HAZE WON’T IMPACT\n',
#  '\n',
#  '1533919687850\n',
#  '1335\n',
#  'HOPEFULLY THE HAZE WON’T IMPACT\n',
#  'THE VIEWING.\n',
#  '\n',
#  '1533919689184\n',
#  '2336\n',
#  'THE VIEWING.\n',
#  'TODAY THE SOUTH LAKE UNION BLOC\n',
#  '\n',
#  '1533919691520\n',
#  '3470\n',
#  'TODAY THE SOUTH LAKE UNION BLOC\n',
#  'PARTY IS GOING ON THIS WEEKEND\n',
#  '\n',
#  '1533919694990\n',
#  '467\n',
#  'PARTY IS GOING ON THIS WEEKEND\n',
#  'TASTE ADMITS.\n',
#  '\n',
#  '1533919695457\n',
#  '2336\n',
#  'TASTE ADMITS.\n',
#  'THE FESTIVAL AT MOUNT SIDE.\n',
#  '\n',
#  '1533919697793\n',
#  '601\n',
#  'THE FESTIVAL AT MOUNT SIDE.\n',
#  'THE RIVER IN POWWOW IN\n',
#  '\n',
#  '1533919698394\n',
#  '4571\n',
#  'THE RIVER IN POWWOW IN\n',
#  'ARLINGTON.\n',
#  '\n',
#  '1533919702965\n',
#  '1168\n',
#  'ARLINGTON.\n',
#  'THE SAME AS LAWNMOWER RACES.\n',
#  '\n',
#  '1533919704133\n',
#  '667\n',
#  'THE SAME AS LAWNMOWER RACES.\n',
#  'THAT’S WHAT I PUT THERE AND\n',
#  '\n',
#  '1533919704800\n',
#  '2769\n',
#  'THAT’S WHAT I PUT THERE AND\n',
#  'SATURDAY AUBURN FESTIVAL.\n',
#  '\n',
#  '1533919707570\n',
#  '1401\n',
#  'SATURDAY AUBURN FESTIVAL.\n',
#  'LOTS TO DO A GOOD WEATHER FOR\n',
#  '\n',
#  '1533919708971\n',
#  '400\n',
#  'LOTS TO DO A GOOD WEATHER FOR\n',
#  'IT.\n',
#  '\n',
#  '1533919709371\n',
#  '1001\n',
#  'IT.\n',
#  'HERE IS ADAM.\n',
#  '\n',
#  '1533919710372\n',
#  '1568\n',
#  'HERE IS ADAM.\n',
#  '>> KEEPING AN EYE WANTS\n',
#  '\n',
#  '1533919711941\n',
#  '2035\n',
#  '>> KEEPING AN EYE WANTS\n',
#  'HAPPENING NORTHBOUND I-5 AT THE\n',
#  '\n',
#  '1533919713976\n',
#  '734\n',
#  'HAPPENING NORTHBOUND I-5 AT THE\n',
#  'SHIP CANAL BRIDGE BROKEN DOWN\n',
#  '\n',
#  '1533919714710\n',
#  '1768\n',
#  'SHIP CANAL BRIDGE BROKEN DOWN\n',
#  'SEMI STILL SITS IN THE RIGHT\n',
#  '\n',
#  '1533919716478\n',
#  '1602\n',
#  'SEMI STILL SITS IN THE RIGHT\n',
#  'LANE IT’S BEEN THERE FOR WHAT\n',
#  '\n',
#  '1533919718080\n',
#  '1034\n',
#  'LANE IT’S BEEN THERE FOR WHAT\n',
#  'FEELS LIKE FOREVER.\n',
#  '\n',
#  '1533919719114\n',
#  '1268\n',
#  'FEELS LIKE FOREVER.\n',
#  'THE BACKUPS CONTINUE NORTHBOUND\n',
#  '\n',
#  '1533919720382\n',
#  '1301\n',
#  'THE BACKUPS CONTINUE NORTHBOUND\n',
#  'I-5 FROM MICHIGAN CURVE LEADING\n',
#  '\n',
#  '1533919721683\n',
#  '901\n',
#  'I-5 FROM MICHIGAN CURVE LEADING\n',
#  'UP TO THIS POINT.\n',
#  '\n',
#  '1533919722584\n',
#  '2202\n',
#  'UP TO THIS POINT.\n',
#  'WE SEE NORTH 99 WITH THE\n',
#  '\n',
#  '1533919724786\n',
#  '1201\n',
#  'WE SEE NORTH 99 WITH THE\n',
#  'CROWDING MOVING INTO DOWNTOWN\n',
#  '\n',
#  '1533919725988\n',
#  '1401\n',
#  'CROWDING MOVING INTO DOWNTOWN\n',
#  'SEATTLE.\n',
#  '\n',
#  '1533919727389\n',
#  '1368\n',
#  'SEATTLE.\n',
#  'NORTH 405 SLOWING RENTON CURVES\n',
#  '\n',
#  '1533919728757\n',
#  '701\n',
#  'NORTH 405 SLOWING RENTON CURVES\n',
#  'TO KENNYDALE AND NEWCASTLE BY\n',
#  '\n',
#  '1533919729458\n',
#  '2135\n',
#  'TO KENNYDALE AND NEWCASTLE BY\n',
#  'THE REST OF THE SOUND STARTING\n',
#  '\n',
#  '1533919731593\n',
#  '13747\n',
#  'THE REST OF THE SOUND STARTING\n',
#  'TO EASE UP AT LEAST FOR THE\n',
#  '\n',
#  '1533919745340\n',
#  '334\n',
#  'TO EASE UP AT LEAST FOR THE\n',
#  'MOMENT.\n',
#  '\n',
#  '1533919745674\n',
#  '734\n',
#  'MOMENT.\n',
#  'WHAT I’M CALLING THIS THE QUIET\n',
#  '\n',
#  '1533919746408\n',
#  '501\n',
#  'WHAT I’M CALLING THIS THE QUIET\n',
#  'BEFORE THE STORM.\n',
#  '\n',
#  '1533919746908\n',
#  '734\n',
#  'BEFORE THE STORM.\n',
#  'THIS AFTERNOON’S COMMUTE I HAVE\n',
#  '\n',
#  '1533919747643\n',
#  '734\n',
#  'THIS AFTERNOON’S COMMUTE I HAVE\n',
#  'A FEELING GOING TO BE 1 OF EPIC\n',
#  '\n',
#  '1533919748377\n',
#  '701\n',
#  'A FEELING GOING TO BE 1 OF EPIC\n',
#  'PROPORTIONS OF YOU GOT ON THE\n',
#  '\n',
#  '1533919749077\n',
#  '734\n',
#  'PROPORTIONS OF YOU GOT ON THE\n',
#  'PEARL JAM FANS ALL TRYING TO GET\n',
#  '\n',
#  '1533919749811\n',
#  '734\n',
#  'PEARL JAM FANS ALL TRYING TO GET\n',
#  'TOWARDS THE SADDLE AREA AND ALL\n',
#  '\n',
#  '1533919750545\n',
#  '701\n',
#  'TOWARDS THE SADDLE AREA AND ALL\n',
#  'THE OTHER FOLKS TRYING TO GET\n',
#  '\n',
#  '1533919751246\n',
#  '400\n',
#  'THE OTHER FOLKS TRYING TO GET\n',
#  'OUT OF TOWN.\n',
#  '\n',
#  '1533919751647\n',
#  '601\n',
#  'OUT OF TOWN.\n',
#  'I FEEL FOR YOU ALREADY.\n',
#  '\n',
#  '1533919752247\n',
#  '767\n',
#  'I FEEL FOR YOU ALREADY.\n',
#  'SOUTHBOUND 5 SOUTHBOUND 405 DOWN\n',
#  '\n',
#  '1533919753015\n',
#  '634\n',
#  'SOUTHBOUND 5 SOUTHBOUND 405 DOWN\n',
#  'THROUGH THE KING SNOHOMISH\n',
#  '\n',
#  '1533919753649\n',
#  '767\n',
#  'THROUGH THE KING SNOHOMISH\n',
#  'COUNTY LINE IT ALSO CONTINUES TO\n',
#  '\n',
#  '1533919754416\n',
#  '1168\n',
#  'COUNTY LINE IT ALSO CONTINUES TO\n',
#  'HAVE A BUILDUP TO IT RIGHT ABOUT\n',
#  '\n',
#  '1533919755584\n',
#  '300\n',
#  'HAVE A BUILDUP TO IT RIGHT ABOUT\n',
#  'NOW.\n',
#  '\n',
#  '1533919755884\n',
#  '1702\n',
#  'NOW.\n',
#  'U.S. 2 CHICKS IN JUST FINE\n',
#  '\n',
#  '1533919757586\n',
#  '667\n',
#  'U.S. 2 CHICKS IN JUST FINE\n',
#  'THROUGH THE NORTH.\n',
#  '\n',
#  '1533919758253\n',
#  '2202\n',
#  'THROUGH THE NORTH.\n',
#  'ALEX AND BILL BACK OVER TO YOU.\n',
#  '\n',
#  '1533919760455\n',
#  '434\n',
#  'ALEX AND BILL BACK OVER TO YOU.\n',
#  '>> OKAY.\n',
#  '\n',
#  '1533919760889\n',
#  '2102\n',
#  '>> OKAY.\n',
#  'COULD BE A BIG SHIFT FOR THE\n',
#  '\n',
#  '1533919762991\n',
#  '968\n',
#  'COULD BE A BIG SHIFT FOR THE\n',
#  'JAMES BOND FRANCHISE.\n',
#  '\n',
#  '1533919763959\n',
#  '1335\n',
#  'JAMES BOND FRANCHISE.\n',
#  'TRAVIS JOINING US NEXT WITH THE\n',
#  '\n',
#  '1533919765294\n',
#  '3904\n',
#  'TRAVIS JOINING US NEXT WITH THE\n',
#  'TRUTH AND THE HYPE BEHIND THE\n',
#  '\n',
#  '1533919769197\n',
#  '767\n',
#  'TRUTH AND THE HYPE BEHIND THE\n',
#  'LATEST INTERNET RUMOR ABOUT\n',
#  '\n',
#  '1533919769965\n',
#  '1168\n',
#  'LATEST INTERNET RUMOR ABOUT\n',
#  'THROUGH THE NEW JAMES BOND COULD\n',
#  '\n',
#  '1533919771133\n',
#  '267\n',
#  'THROUGH THE NEW JAMES BOND COULD\n',
#  'BE.\n',
#  '\n',
#  '1533919771400\n',
#  '801\n',
#  'BE.\n',
#  '>> PLUS AFTER THAT DID YOU KNOW\n',
#  '\n',
#  '1533919772200\n',
#  '2669\n',
#  '>> PLUS AFTER THAT DID YOU KNOW\n',
#  'IT’S NATIONAL\n',
#  '\n',
#  '1533919774870\n',
#  '701\n',
#  'IT’S NATIONAL\n',
#  'S’MORES DAY AND WE’RE MAKING\n',
#  '\n',
#  '1533919775570\n',
#  '1168\n',
#  'S’MORES DAY AND WE’RE MAKING\n',
#  'SOME DELICIOUS S’MORES IN OUR\n',
#  '\n',
#  '1533919776738\n',
#  '701\n',
#  'SOME DELICIOUS S’MORES IN OUR\n',
#  'STUDIOS AND SHOWING YOU THEO\n',
#  '\n',
#  '1533919777439\n',
#  '3170\n',
#  'STUDIOS AND SHOWING YOU THEO\n',
#  'CHOCOLATE IS HELPING PEARL JAM.\n',
#  '\n',
#  '1533919780609\n',
#  '172339\n',
#  'CHOCOLATE IS HELPING PEARL JAM.\n',
#  'WE WILL BE RIGHT BACK.\n',
#  '\n',
#  '1533919952948\n',
#  '1468\n',
#  'WE WILL BE RIGHT BACK.\n',
#  '[MUSIC PLAYING]\n',
#  '\n',
#  '1533919954416\n',
#  '9009\n',
#  '[MUSIC PLAYING]\n',
#  '[MUSIC PLAYING]\n',
#  '\n',
#  '1533919963425\n',
#  '2569\n',
#  '[MUSIC PLAYING]\n',
#  '>> THEY WERE SHOOTING 1 JAMES\n',
#  '\n',
#  '1533919965994\n',
#  '3237\n',
#  '>> THEY WERE SHOOTING 1 JAMES\n',
#  'BOND FILM AND WHEN WAS IT?\n',
#  '\n',
#  '1533919969231\n',
#  '4204\n',
#  'BOND FILM AND WHEN WAS IT?\n',
#  'IT MUST HAVE BEEN TIMOTHY DALTON\n',
#  '\n',
#  '1533919973435\n',
#  '601\n',
#  'IT MUST HAVE BEEN TIMOTHY DALTON\n',
#  'ERA.\n',
#  '\n',
#  '1533919974035\n',
#  '1702\n',
#  'ERA.\n',
#  'THEY WERE SHOOTING AT ON\n',
#  '\n',
#  '1533919975737\n',
#  '767\n',
#  'THEY WERE SHOOTING AT ON\n',
#  'NOVEMBER 10 I WAS IN LONDON 1\n',
#  '\n',
#  '1533919976504\n',
#  '767\n',
#  'NOVEMBER 10 I WAS IN LONDON 1\n',
#  'TIME HE WAS CRUISING ALONG ON A\n',
#  '\n',
#  '1533919977272\n',
#  '4271\n',
#  'TIME HE WAS CRUISING ALONG ON A\n',
#  'BOAT THEY WERE DOING A SCENE.\n',
#  '\n',
#  '1533919981543\n',
#  '534\n',
#  'BOAT THEY WERE DOING A SCENE.\n',
#  'THAT IS JAMES BOND.\n',
#  '\n',
#  '1533919982077\n',
#  '3070\n',
#  'THAT IS JAMES BOND.\n',
#  '>> CLEARLY JAMES BOND.\n',
#  '\n',
#  '1533919985146\n',
#  '701\n',
#  '>> CLEARLY JAMES BOND.\n',
#  '>> BEING CHASED BY A SMALL\n',
#  '\n',
#  '1533919985847\n',
#  '4538\n',
#  '>> BEING CHASED BY A SMALL\n',
#  'DINGHY THERE.\n',
#  '\n',
#  '1533919990385\n',
#  '3003\n',
#  'DINGHY THERE.\n',
#  '>> YOU WILL NOT GET ME.\n',
#  '\n',
#  '1533919993388\n',
#  '300\n',
#  '>> YOU WILL NOT GET ME.\n',
#  'OKAY.\n',
#  '\n',
#  '1533919993688\n',
#  '1468\n',
#  'OKAY.\n',
#  '9:53 RIGHT NOW.\n',
#  '\n',
#  '1533919995156\n',
#  '1001\n',
#  '9:53 RIGHT NOW.\n',
#  'IN EVERY OFFICIAL MOVIE MADE SO\n',
#  '\n',
#  '1533919996157\n',
#  '734\n',
#  'IN EVERY OFFICIAL MOVIE MADE SO\n',
#  'FAR, JAMES BOND HAS ALWAYS BEEN\n',
#  '\n',
#  '1533919996892\n',
#  '400\n',
#  'FAR, JAMES BOND HAS ALWAYS BEEN\n',
#  'A WHITE GUY.\n',
#  '\n',
#  '1533919997292\n',
#  '2302\n',
#  'A WHITE GUY.\n',
#  '>> NOW THE INTERNET IS OBSESSING\n',
#  '\n',
#  '1533919999594\n',
#  '5739\n',
#  '>> NOW THE INTERNET IS OBSESSING\n',
#  'OVER A RUMOR THE NEXT BOND COULD\n',
#  '\n',
#  '1533920005333\n',
#  '467\n',
#  'OVER A RUMOR THE NEXT BOND COULD\n',
#  'BE A BLACK GUY.\n',
#  '\n',
#  '1533920005800\n',
#  '667\n',
#  'BE A BLACK GUY.\n',
#  'WHAT IS GOING ON.\n',
#  '\n',
#  '1533920006468\n',
#  '767\n',
#  'WHAT IS GOING ON.\n',
#  '>> THIS IS TRENDING EVERYWHERE\n',
#  '\n',
#  '1533920007235\n',
#  '701\n',
#  '>> THIS IS TRENDING EVERYWHERE\n',
#  'THIS MORNING AND EVERYONE IS\n',
#  '\n',
#  '1533920007936\n',
#  '1768\n',
#  'THIS MORNING AND EVERYONE IS\n',
#  'SHARING THIS.\n',
#  '\n',
#  '1533920009704\n',
#  '2169\n',
#  'SHARING THIS.\n',
#  'THIS IS THE 1 THAT HAPPENED\n',
#  '\n',
#  '1533920011873\n',
#  '868\n',
#  'THIS IS THE 1 THAT HAPPENED\n',
#  'OVERNIGHT.\n',
#  '\n',
#  '1533920012741\n',
#  '801\n',
#  'OVERNIGHT.\n',
#  'JAMES BOND PRODUCERS ARE\n',
#  '\n',
#  ...]

# %%
data[0]
# Out:
# '1533919500396\n'

# %%
data_joined = " ".join(data)
data_joined
# Out:
# '1533919500396\n 1068\n YEAR SEAHAWKS TEAM INCLUDING\n SOMEONE WHO IMPRESS A WHOLE LOT\n \n 1533919501464\n 1134\n SOMEONE WHO IMPRESS A WHOLE LOT\n OF PEOPLE.\n \n 1533919502599\n 834\n OF PEOPLE.\n ALL ACROSS THE COUNTRY WITH HIS\n \n 1533919503433\n 2402\n ALL ACROSS THE COUNTRY WITH HIS\n DEBUT LAST NIGHT.\n \n 1533919505835\n 2169\n DEBUT LAST NIGHT.\n >> EVERY FAN IN THE COUNTRY IS A\n \n 1533919508004\n 2169\n >> EVERY FAN IN THE COUNTRY IS A\n FAN OF THIS GENTLEMAN.\n \n 1533919510173\n 767\n FAN OF THIS GENTLEMAN.\n RECORDING 4 TACKLES IN HIS FIRST\n \n 1533919510940\n 3670\n RECORDING 4 TACKLES IN HIS FIRST\n 4 SNAPS.\n \n 1533919514611\n 2202\n 4 SNAPS.\n THE LEADING TACKLER IN THE GAME.\n \n 1533919516813\n 1401\n THE LEADING TACKLER IN THE GAME.\n CLOSER LOOK AT THAT ROOKIE\n \n 1533919518214\n 400\n CLOSER LOOK AT THAT ROOKIE\n LINEBACKER.\n \n 1533919518615\n 3804\n LINEBACKER.\n >> MEET NUMBER 49.\n \n 1533919522418\n 667\n >> MEET NUMBER 49.\n THE ATHLETIC LINEBACKER WAS\n \n 1533919523086\n 1969\n THE ATHLETIC LINEBACKER WAS\n SELECTED BY THE SEAHAWKS IN THE\n \n 1533919525054\n 701\n SELECTED BY THE SEAHAWKS IN THE\n FIFTH ROUND REUNITING HIM WITH\n \n 1533919525755\n 1935\n FIFTH ROUND REUNITING HIM WITH\n HIS TWIN BROTHER.\n \n 1533919527690\n 3003\n HIS TWIN BROTHER.\n >> HELLO.\n \n 1533919530693\n 467\n >> HELLO.\n >> YES SIR.\n \n 1533919531160\n 2769\n >> YES SIR.\n IT’S JOHN SCHNEIDER CALLING HOW\n \n 1533919533929\n 3871\n IT’S JOHN SCHNEIDER CALLING HOW\n ARE YOU DOING?\n \n 1533919537800\n 767\n ARE YOU DOING?\n >> I CAN’T EVEN BREATHE RIGHT\n \n 1533919538567\n 267\n >> I CAN’T EVEN BREATHE RIGHT\n NOW.\n \n 1533919538834\n 3003\n NOW.\n >> BOTH BROTHERS OFFERED\n \n 1533919541837\n 968\n >> BOTH BROTHERS OFFERED\n SCHOLARSHIPS TO THE UNIVERSITY\n \n 1533919542805\n 734\n SCHOLARSHIPS TO THE UNIVERSITY\n OF CENTRAL FLORIDA WHERE THEY\n \n 1533919543539\n 4037\n OF CENTRAL FLORIDA WHERE THEY\n PLAYED TOGETHER.\n \n 1533919547576\n 2836\n PLAYED TOGETHER.\n THE SENIOR YEAR SHE LEAD THE\n \n 1533919550413\n 1535\n THE SENIOR YEAR SHE LEAD THE\n NINTH 21st EVER UNDEFEATED\n \n 1533919551947\n 334\n NINTH 21st EVER UNDEFEATED\n RECORD.\n \n 1533919552281\n 2035\n RECORD.\n FINISHING 13 AND 0 AND NAMED A\n \n 1533919554316\n 1902\n FINISHING 13 AND 0 AND NAMED A\n SECOND-TEAM ALL-AMERICAN.\n \n 1533919556218\n 1034\n SECOND-TEAM ALL-AMERICAN.\n GRIFFIN UNDER THE NFL DRAFT AND\n \n 1533919557253\n 2769\n GRIFFIN UNDER THE NFL DRAFT AND\n 1 OF THE LAST TO BE INVITED TO\n \n 1533919560022\n 1168\n 1 OF THE LAST TO BE INVITED TO\n THE NFL COMBINE WHERE HE WOWED\n \n 1533919561190\n 1235\n THE NFL COMBINE WHERE HE WOWED\n THE SCOUTS.\n \n 1533919562425\n 3103\n THE SCOUTS.\n RAN A 4.3840-YARD-AND PUT UP 20\n \n 1533919565528\n 1702\n RAN A 4.3840-YARD-AND PUT UP 20\n REPS ON THE BENCH PRESS USING A\n \n 1533919567229\n 868\n REPS ON THE BENCH PRESS USING A\n SPECIAL PROSTHETIC STRAPPED TO\n \n 1533919568097\n 2503\n SPECIAL PROSTHETIC STRAPPED TO\n HIS LEFT ARM.\n \n 1533919570599\n 1401\n HIS LEFT ARM.\n HE LOST HIS LEFT HAND DUE TO A\n \n 1533919572001\n 2236\n HE LOST HIS LEFT HAND DUE TO A\n RARE CONDITION AT THE AGE OF 4.\n \n 1533919574236\n 1969\n RARE CONDITION AT THE AGE OF 4.\n AND YOU CAN TELL THAT HASN’T\n \n 1533919576205\n 467\n AND YOU CAN TELL THAT HASN’T\n STOPPED HIM.\n \n 1533919576672\n 1235\n STOPPED HIM.\n HIS BROTHER SAYS HE AND THE TEAM\n \n 1533919577907\n 1702\n HIS BROTHER SAYS HE AND THE TEAM\n ARE GLAD TO HAVE HIM.\n \n 1533919579608\n 1468\n ARE GLAD TO HAVE HIM.\n >> I KNOW HE’S GOING TO WORK\n \n 1533919581077\n 701\n >> I KNOW HE’S GOING TO WORK\n HARD AND PUSH EVERYBODY AROUND\n \n 1533919581777\n 1401\n HARD AND PUSH EVERYBODY AROUND\n HIM.\n \n 1533919583179\n 2936\n HIM.\n THAT’S HOW I MAKE PLAYS.\n \n 1533919586115\n 1468\n THAT’S HOW I MAKE PLAYS.\n WE BRING THE ATMOSPHERE BACK\n \n 1533919587583\n 1802\n WE BRING THE ATMOSPHERE BACK\n TRYING TO BEAT EACH OTHER OUT\n \ ...

# %%
data_joined = data_joined.strip().split()

# %%
data_joined
# Out:
# ['1533919500396',
#  '1068',
#  'YEAR',
#  'SEAHAWKS',
#  'TEAM',
#  'INCLUDING',
#  'SOMEONE',
#  'WHO',
#  'IMPRESS',
#  'A',
#  'WHOLE',
#  'LOT',
#  '1533919501464',
#  '1134',
#  'SOMEONE',
#  'WHO',
#  'IMPRESS',
#  'A',
#  'WHOLE',
#  'LOT',
#  'OF',
#  'PEOPLE.',
#  '1533919502599',
#  '834',
#  'OF',
#  'PEOPLE.',
#  'ALL',
#  'ACROSS',
#  'THE',
#  'COUNTRY',
#  'WITH',
#  'HIS',
#  '1533919503433',
#  '2402',
#  'ALL',
#  'ACROSS',
#  'THE',
#  'COUNTRY',
#  'WITH',
#  'HIS',
#  'DEBUT',
#  'LAST',
#  'NIGHT.',
#  '1533919505835',
#  '2169',
#  'DEBUT',
#  'LAST',
#  'NIGHT.',
#  '>>',
#  'EVERY',
#  'FAN',
#  'IN',
#  'THE',
#  'COUNTRY',
#  'IS',
#  'A',
#  '1533919508004',
#  '2169',
#  '>>',
#  'EVERY',
#  'FAN',
#  'IN',
#  'THE',
#  'COUNTRY',
#  'IS',
#  'A',
#  'FAN',
#  'OF',
#  'THIS',
#  'GENTLEMAN.',
#  '1533919510173',
#  '767',
#  'FAN',
#  'OF',
#  'THIS',
#  'GENTLEMAN.',
#  'RECORDING',
#  '4',
#  'TACKLES',
#  'IN',
#  'HIS',
#  'FIRST',
#  '1533919510940',
#  '3670',
#  'RECORDING',
#  '4',
#  'TACKLES',
#  'IN',
#  'HIS',
#  'FIRST',
#  '4',
#  'SNAPS.',
#  '1533919514611',
#  '2202',
#  '4',
#  'SNAPS.',
#  'THE',
#  'LEADING',
#  'TACKLER',
#  'IN',
#  'THE',
#  'GAME.',
#  '1533919516813',
#  '1401',
#  'THE',
#  'LEADING',
#  'TACKLER',
#  'IN',
#  'THE',
#  'GAME.',
#  'CLOSER',
#  'LOOK',
#  'AT',
#  'THAT',
#  'ROOKIE',
#  '1533919518214',
#  '400',
#  'CLOSER',
#  'LOOK',
#  'AT',
#  'THAT',
#  'ROOKIE',
#  'LINEBACKER.',
#  '1533919518615',
#  '3804',
#  'LINEBACKER.',
#  '>>',
#  'MEET',
#  'NUMBER',
#  '49.',
#  '1533919522418',
#  '667',
#  '>>',
#  'MEET',
#  'NUMBER',
#  '49.',
#  'THE',
#  'ATHLETIC',
#  'LINEBACKER',
#  'WAS',
#  '1533919523086',
#  '1969',
#  'THE',
#  'ATHLETIC',
#  'LINEBACKER',
#  'WAS',
#  'SELECTED',
#  'BY',
#  'THE',
#  'SEAHAWKS',
#  'IN',
#  'THE',
#  '1533919525054',
#  '701',
#  'SELECTED',
#  'BY',
#  'THE',
#  'SEAHAWKS',
#  'IN',
#  'THE',
#  'FIFTH',
#  'ROUND',
#  'REUNITING',
#  'HIM',
#  'WITH',
#  '1533919525755',
#  '1935',
#  'FIFTH',
#  'ROUND',
#  'REUNITING',
#  'HIM',
#  'WITH',
#  'HIS',
#  'TWIN',
#  'BROTHER.',
#  '1533919527690',
#  '3003',
#  'HIS',
#  'TWIN',
#  'BROTHER.',
#  '>>',
#  'HELLO.',
#  '1533919530693',
#  '467',
#  '>>',
#  'HELLO.',
#  '>>',
#  'YES',
#  'SIR.',
#  '1533919531160',
#  '2769',
#  '>>',
#  'YES',
#  'SIR.',
#  'IT’S',
#  'JOHN',
#  'SCHNEIDER',
#  'CALLING',
#  'HOW',
#  '1533919533929',
#  '3871',
#  'IT’S',
#  'JOHN',
#  'SCHNEIDER',
#  'CALLING',
#  'HOW',
#  'ARE',
#  'YOU',
#  'DOING?',
#  '1533919537800',
#  '767',
#  'ARE',
#  'YOU',
#  'DOING?',
#  '>>',
#  'I',
#  'CAN’T',
#  'EVEN',
#  'BREATHE',
#  'RIGHT',
#  '1533919538567',
#  '267',
#  '>>',
#  'I',
#  'CAN’T',
#  'EVEN',
#  'BREATHE',
#  'RIGHT',
#  'NOW.',
#  '1533919538834',
#  '3003',
#  'NOW.',
#  '>>',
#  'BOTH',
#  'BROTHERS',
#  'OFFERED',
#  '1533919541837',
#  '968',
#  '>>',
#  'BOTH',
#  'BROTHERS',
#  'OFFERED',
#  'SCHOLARSHIPS',
#  'TO',
#  'THE',
#  'UNIVERSITY',
#  '1533919542805',
#  '734',
#  'SCHOLARSHIPS',
#  'TO',
#  'THE',
#  'UNIVERSITY',
#  'OF',
#  'CENTRAL',
#  'FLORIDA',
#  'WHERE',
#  'THEY',
#  '1533919543539',
#  '4037',
#  'OF',
#  'CENTRAL',
#  'FLORIDA',
#  'WHERE',
#  'THEY',
#  'PLAYED',
#  'TOGETHER.',
#  '1533919547576',
#  '2836',
#  'PLAYED',
#  'TOGETHER.',
#  'THE',
#  'SENIOR',
#  'YEAR',
#  'SHE',
#  'LEAD',
#  'THE',
#  '1533919550413',
#  '1535',
#  'THE',
#  'SENIOR',
#  'YEAR',
#  'SHE',
#  'LEAD',
#  'THE',
#  'NINTH',
#  '21st',
#  'EVER',
#  'UNDEFEATED',
#  '1533919551947',
#  '334',
#  'NINTH',
#  '21st',
#  'EVER',
#  'UNDEFEATED',
#  'RECORD.',
#  '1533919552281',
#  '2035',
#  'RECORD.',
#  'FINISHING',
#  '13',
#  'AND',
#  '0',
#  'AND',
#  'NAMED',
#  'A',
#  '1533919554316',
#  '1902',
#  'FINISHING',
#  '13',
#  'AND',
#  '0',
#  'AND',
#  'NAMED',
#  'A',
#  'SECOND-TEAM',
#  'ALL-AMERICAN.',
#  '1533919556218',
#  '1034',
#  'SECOND-TEAM',
#  'ALL-AMERICAN.',
#  'GRIFFIN',
#  'UNDER',
#  'THE',
#  'NFL',
#  'DRAFT',
#  'AND',
#  '1533919557253',
#  '2769',
#  'GRIFFIN',
#  'UNDER',
#  'THE',
#  'NFL',
#  'DRAFT',
#  'AND',
#  '1',
#  'OF',
#  'THE',
#  'LAST',
#  'TO',
#  'BE',
#  'INVITED',
#  'TO',
#  '1533919560022',
#  '1168',
#  '1',
#  'OF',
#  'THE',
#  'LAST',
#  'TO',
#  'BE',
#  'INVITED',
#  'TO',
#  'THE',
#  'NFL',
#  'COMBINE',
#  'WHERE',
#  'HE',
#  'WOWED',
#  '1533919561190',
#  '1235',
#  'THE',
#  'NFL',
#  'COMBINE',
#  'WHERE',
#  'HE',
#  'WOWED',
#  'THE',
#  'SCOUTS.',
#  '1533919562425',
#  '3103',
#  'THE',
#  'SCOUTS.',
#  'RAN',
#  'A',
#  '4.3840-YARD-AND',
#  'PUT',
#  'UP',
#  '20',
#  '1533919565528',
#  '1702',
#  'RAN',
#  'A',
#  '4.3840-YARD-AND',
#  'PUT',
#  'UP',
#  '20',
#  'REPS',
#  'ON',
#  'THE',
#  'BENCH',
#  'PRESS',
#  'USING',
#  'A',
#  '1533919567229',
#  '868',
#  'REPS',
#  'ON',
#  'THE',
#  'BENCH',
#  'PRESS',
#  'USING',
#  'A',
#  'SPECIAL',
#  'PROSTHETIC',
#  'STRAPPED',
#  'TO',
#  '1533919568097',
#  '2503',
#  'SPECIAL',
#  'PROSTHETIC',
#  'STRAPPED',
#  'TO',
#  'HIS',
#  'LEFT',
#  'ARM.',
#  '1533919570599',
#  '1401',
#  'HIS',
#  'LEFT',
#  'ARM.',
#  'HE',
#  'LOST',
#  'HIS',
#  'LEFT',
#  'HAND',
#  'DUE',
#  'TO',
#  'A',
#  '1533919572001',
#  '2236',
#  'HE',
#  'LOST',
#  'HIS',
#  'LEFT',
#  'HAND',
#  'DUE',
#  'TO',
#  'A',
#  'RARE',
#  'CONDITION',
#  'AT',
#  'THE',
#  'AGE',
#  'OF',
#  '4.',
#  '1533919574236',
#  '1969',
#  'RARE',
#  'CONDITION',
#  'AT',
#  'THE',
#  'AGE',
#  'OF',
#  '4.',
#  'AND',
#  'YOU',
#  'CAN',
#  'TELL',
#  'THAT',
#  'HASN’T',
#  '1533919576205',
#  '467',
#  'AND',
#  'YOU',
#  'CAN',
#  'TELL',
#  'THAT',
#  'HASN’T',
#  'STOPPED',
#  'HIM.',
#  '1533919576672',
#  '1235',
#  'STOPPED',
#  'HIM.',
#  'HIS',
#  'BROTHER',
#  'SAYS',
#  'HE',
#  'AND',
#  'THE',
#  'TEAM',
#  '1533919577907',
#  '1702',
#  'HIS',
#  'BROTHER',
#  'SAYS',
#  'HE',
#  'AND',
#  'THE',
#  'TEAM',
#  'ARE',
#  'GLAD',
#  'TO',
#  'HAVE',
#  'HIM.',
#  '1533919579608',
#  '1468',
#  'ARE',
#  'GLAD',
#  'TO',
#  'HAVE',
#  'HIM.',
#  '>>',
#  'I',
#  'KNOW',
#  'HE’S',
#  'GOING',
#  'TO',
#  'WORK',
#  '1533919581077',
#  '701',
#  '>>',
#  'I',
#  'KNOW',
#  'HE’S',
#  'GOING',
#  'TO',
#  'WORK',
#  'HARD',
#  'AND',
#  'PUSH',
#  'EVERYBODY',
#  'AROUND',
#  '1533919581777',
#  '1401',
#  'HARD',
#  'AND',
#  'PUSH',
#  'EVERYBODY',
#  'AROUND',
#  'HIM.',
#  '1533919583179',
#  '2936',
#  'HIM.',
#  'THAT’S',
#  'HOW',
#  'I',
#  'MAKE',
#  'PLAYS.',
#  '1533919586115',
#  '1468',
#  'THAT’S',
#  'HOW',
#  'I',
#  'MAKE',
#  'PLAYS.',
#  'WE',
#  'BRING',
#  'THE',
#  'ATMOSPHERE',
#  'BACK',
#  '1533919587583',
#  '1802',
#  'WE',
#  'BRING',
#  'THE',
#  'ATMOSPHERE',
#  'BACK',
#  'TRYING',
#  'TO',
#  'BEAT',
#  'EACH',
#  'OTHER',
#  'OUT',
#  '1533919589385',
#  '1235',
#  'TRYING',
#  'TO',
#  'BEAT',
#  'EACH',
#  'OTHER',
#  'OUT',
#  'EVERYTHING',
#  'AS',
#  'A',
#  'COMPETITION.',
#  '1533919590619',
#  '1802',
#  'EVERYTHING',
#  'AS',
#  'A',
#  'COMPETITION.',
#  'WHAT',
#  'HE',
#  'BRINGS',
#  'TO',
#  'THE',
#  'TABLE',
#  'HIGH',
#  '1533919592421',
#  '767',
#  'WHAT',
#  'HE',
#  'BRINGS',
#  'TO',
#  'THE',
#  'TABLE',
#  'HIGH',
#  'ENERGY',
#  'AND',
#  'YOU',
#  'CAN',
#  'TELL',
#  'HE',
#  'LOVES',
#  '1533919593189',
#  '1401',
#  'ENERGY',
#  'AND',
#  'YOU',
#  'CAN',
#  'TELL',
#  'HE',
#  'LOVES',
#  'THE',
#  'GAME',
#  'AND',
#  'BOTH',
#  'PASSIONATE',
#  '1533919594590',
#  '1869',
#  'THE',
#  'GAME',
#  'AND',
#  'BOTH',
#  'PASSIONATE',
#  'ABOUT',
#  'IT.',
#  '1533919596459',
#  '2936',
#  'ABOUT',
#  'IT.',
#  'HIS',
#  'PRESENCE',
#  'ALONE',
#  'IS',
#  'A',
#  'GREAT',
#  '1533919599395',
#  '2169',
#  'HIS',
#  'PRESENCE',
#  'ALONE',
#  'IS',
#  'A',
#  'GREAT',
#  'FOR',
#  'EVERYBODY.',
#  '1533919601564',
#  '834',
#  'FOR',
#  'EVERYBODY.',
#  '>>',
#  'LIKELY',
#  'PLAY',
#  'WEAK',
#  'SIDE',
#  '1533919602398',
#  '801',
#  '>>',
#  'LIKELY',
#  'PLAY',
#  'WEAK',
#  'SIDE',
#  'LINEBACKER',
#  'ON',
#  'DEFENSE',
#  'AND',
#  '1533919603199',
#  '734',
#  'LINEBACKER',
#  'ON',
#  'DEFENSE',
#  'AND',
#  'CONTRIBUTE',
#  'ON',
#  'SPECIAL',
#  'TEAMS',
#  'IN',
#  '1533919603933',
#  '3270',
#  'CONTRIBUTE',
#  'ON',
#  'SPECIAL',
#  'TEAMS',
#  'IN',
#  'THE',
#  'ROOKIE',
#  'YEAR.',
#  '1533919607203',
#  '2402',
#  'THE',
#  'ROOKIE',
#  'YEAR.',
#  '>>',
#  'WE',
#  'HAVE',
#  'MORE',
#  'OF',
#  'THESE',
#  'STORIES',
#  '1533919609605',
#  '667',
#  '>>',
#  'WE',
#  'HAVE',
#  'MORE',
#  'OF',
#  'THESE',
#  'STORIES',
#  'COMING',
#  'YOUR',
#  'WAY.',
#  '1533919610272',
#  '1201',
#  'COMING',
#  'YOUR',
#  'WAY.',
#  'NEXT',
#  'WEEK',
#  'WILL',
#  'LEARN',
#  'ALL',
#  'ABOUT',
#  '1533919611474',
#  '734',
#  'NEXT',
#  'WEEK',
#  'WILL',
#  'LEARN',
#  'ALL',
#  'ABOUT',
#  'EVERYBODY',
#  'ELSE',
#  'FROM',
#  'NEW',
#  'OFFENSE',
#  '1533919612208',
#  '7941',
#  'EVERYBODY',
#  'ELSE',
#  'FROM',
#  'NEW',
#  'OFFENSE',
#  'OF',
#  'COORDINATOR',
#  'TO',
#  'NEW',
#  '1533919620149',
#  '6440',
#  'OF',
#  'COORDINATOR',
#  'TO',
#  'NEW',
#  'CORNERBACK',
#  'TRE',
#  'FLOWERS.',
#  '1533919626589',
#  '801',
#  'CORNERBACK',
#  'TRE',
#  'FLOWERS.',
#  '>>',
#  'I',
#  'AM',
#  'CAUTIOUSLY',
#  'OPTIMISTIC',
#  '1533919627389',
#  '601',
#  '>>',
#  'I',
#  'AM',
#  'CAUTIOUSLY',
#  'OPTIMISTIC',
#  'ABOUT',
#  'THE',
#  'OFFENSE.',
#  '1533919627990',
#  '1001',
#  'ABOUT',
#  'THE',
#  'OFFENSE.',
#  'I',
#  'LIKE',
#  'WHAT',
#  'THEY’VE',
#  'DONE',
#  'WITH',
#  '1533919628991',
#  '1735',
#  'I',
#  'LIKE',
#  'WHAT',
#  'THEY’VE',
#  'DONE',
#  'WITH',
#  'THE',
#  'OFFENSE',
#  'OF',
#  'LINE',
#  'AND',
#  '1533919630726',
#  '701',
#  'THE',
#  'OFFENSE',
#  'OF',
#  'LINE',
#  'AND',
#  'BACKFIELD',
#  'AND',
#  'WE',
#  'HAVE',
#  'THAT',
#  'GUY',
#  '1533919631427',
#  '3737',
#  'BACKFIELD',
#  'AND',
#  'WE',
#  'HAVE',
#  'THAT',
#  'GUY',
#  'NUMBER',
#  '3',
#  'WHO',
#  'CAN',
#  'DO',
#  'SOME',
#  'THINGS.',
#  '1533919635164',
#  '501',
#  'NUMBER',
#  '3',
#  'WHO',
#  'CAN',
#  'DO',
#  'SOME',
#  'THINGS.',
#  '>>',
#  'ALL',
#  'RIGHT.',
#  '1533919635664',
#  '2903',
#  '>>',
#  'ALL',
#  'RIGHT.',
#  'SOUNDS',
#  'GOOD.',
#  '1533919638567',
#  '501',
#  'SOUNDS',
#  'GOOD.',
#  'LET’S',
#  'GO',
#  'TO',
#  'MJ.',
#  '1533919639068',
#  '2936',
#  'LET’S',
#  'GO',
#  'TO',
#  'MJ.',
#  '>>',
#  'WATCHING',
#  'THE',
#  'GAME',
#  'LAST',
#  'NIGHT',
#  '1533919642004',
#  '1602',
#  '>>',
#  'WATCHING',
#  'THE',
#  'GAME',
#  'LAST',
#  'NIGHT',
#  'FLOWERS',
#  'AT',
#  'THAT',
#  'COACH',
#  'COULD',
#  'GO',
#  '1533919643606',
#  '1068',
#  'FLOWERS',
#  'AT',
#  'THAT',
#  'COACH',
#  'COULD',
#  'GO',
#  'LIKE',
#  'BRING',
#  'ME',
#  'FLOWERS',
#  'AND',
#  'THEY',
#  '1533919644673',
#  '634',
#  'LIKE',
#  'BRING',
#  'ME',
#  'FLOWERS',
#  'AND',
#  'THEY',
#  'WOULD',
#  'BRING',
#  'HIM',
#  'A',
#  'BUNCH',
#  'OF',
#  '1533919645307',
#  '3704',
#  'WOULD',
#  'BRING',
#  'HIM',
#  'A',
#  'BUNCH',
#  'OF',
#  'FLOWERS.',
#  '1533919649011',
#  '334',
#  'FLOWERS.',
#  'ANYWAY.',
#  '1533919649345',
#  '1034',
#  'ANYWAY.',
#  'GRAYSCALE',
#  'DIRECTOR,',
#  'AND',
#  'OLYMPIA',
#  '1533919650379',
#  '1468',
#  'GRAYSCALE',
#  'DIRECTOR,',
#  'AND',
#  'OLYMPIA',
#  'THE',
#  'U-DISTRICT',
#  'KIND',
#  'OF',
#  'HAZY',
#  'WITH',
#  '1533919651847',
#  '1068',
#  'THE',
#  'U-DISTRICT',
#  'KIND',
#  'OF',
#  'HAZY',
#  'WITH',
#  'THE',
#  'SMOKE',
#  'OUT',
#  'THERE.',
#  '1533919652915',
#  '2269',
#  'THE',
#  'SMOKE',
#  'OUT',
#  'THERE.',
#  'CLOUDY',
#  'ON',
#  'THE',
#  'COAST',
#  'IN',
#  'LOOKING',
#  '1533919655184',
#  '534',
#  'CLOUDY',
#  'ON',
#  'THE',
#  'COAST',
#  'IN',
#  'LOOKING',
#  'HAZY',
#  'AND',
#  'BELLINGHAM.',
#  '1533919655718',
#  '1835',
#  'HAZY',
#  'AND',
#  'BELLINGHAM.',
#  'THAT',
#  'WILL',
#  'BE',
#  'THE',
#  'THEME',
#  'TODAY',
#  'THE',
#  '1533919657553',
#  '1368',
#  'THAT',
#  'WILL',
#  'BE',
#  'THE',
#  'THEME',
#  'TODAY',
#  'THE',
#  'HAZY',
#  'SUNSHINE',
#  ...]
